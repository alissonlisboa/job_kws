# %% [markdown]
# - [x] Capturar Número de Vagas
# - [x] Criar lista de links
# - [x] Criar lista com descrições vagas
# - [ ] transformar em um DataFrame
# - [ ] Calcular tf_idf de palavras por vaga

# %% [markdown]
# # Get number of jobs

# %%
from bs4 import BeautifulSoup
import requests

# %%
paginator = 0
r = requests.get(f'https://br.indeed.com/empregos?q=cientista+de+dados&l=brasil&start={paginator}')
page = BeautifulSoup(r.content, 'html.parser')

# %%
n_jobs = int(pagina.find(id='searchCountPages').text.split()[3])
n_jobs
# Out:
# 246

# %% [markdown]
# # Get opportunity links

# %%
job_links = []
for i in range(10, n_opportunities, 10):
    r = requests.get(f'https://br.indeed.com/empregos?q=cientista+de+dados&l=brasil&start={i}')
    page = BeautifulSoup(r.content, 'html.parser')
    anchors = page.find_all('a', class_='jobtitle')
    for a in anchors:
        job_links.append('https://www.indeed.com' + a.get('href'))

# %% [markdown]
# # Get list of job description

# %%
job_description = []
bad_attemps = []
for link in job_links:
    r = requests.get(link)
    page = BeautifulSoup(r.content, 'html.parser')
    try:
        description = page.find('div', class_='jobsearch-jobDescriptionText').text
    except:
        bad_attemps.append(link)
        continue
    job_description.append(description)
        
for link in bad_attemps:
    job_links.remove(link)

# %%
print(len(job_links))
print(len(job_description))
# Out:
# 77
# 77

# %%
job_description
# Out:
# ['Nosso cliente possui a missão de auxiliar as empresas a extrair todo o potencial de Dados e Digital objetivando aumentar seu desempenho, ajudando na transformação, gerando novas alavancas de crescimento e competitividade.\n\nSabemos que grandes resultados só são alcançados com uma grande equipe, por isso procuramos pessoas talentosas e apaixonadas, com desejo de crescer profissionalmente e criar uma trajetória de carreira!\n\nSuas principais responsabilidades serão:\nMapear e priorizar Indicadores RH\n\nModelagem estatística\nDesempenhar papel de liderança no time\nContribuir para tomada de decisão, baseada em dados gerando aumento de eficiência e produtividade via definição e monitoramento de KPIs, comparações com benchmarks internos e externos e indicação de ações/insights estratégicos de RH.\nO que buscamos:\n\nCapacidade analítica\nNível superior completo em matemática, Estatística, Engenharia ou áreas correlatas\nExperiência em Análise e Modelagem Estatística e People Analytic
# ...
