# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
from collections import Counter
import math

# %% [markdown]
# - [x] Capturar Número de Vagas
# - [x] Criar lista de links
# - [x] Criar lista com descrições vagas
# - [x] transformar em um DataFrame
# - [x] Calcular tf_idf de palavras por vaga
# - [ ] Recomendar 10 melhores vagas a partir de palavras-chave inseridas pelo usuario

# %% [markdown]
# # Get number of jobs

# %%
from bs4 import BeautifulSoup
import requests

# %%
paginator = 0
r = requests.get(f'https://br.indeed.com/empregos?q=cientista+de+dados&l=brasil&start={paginator}')
page = BeautifulSoup(r.content, 'html.parser')

# %%
n_jobs = int(pagina.find(id='searchCountPages').text.split()[3])
n_jobs
# Out:
# 246

# %% [markdown]
# # Get opportunity links

# %%
job_links = []
for i in range(0, n_jobs, 10):
    r = requests.get(f'https://br.indeed.com/empregos?q=cientista+de+dados&l=brasil&start={i}')
    page = BeautifulSoup(r.content, 'html.parser')
    anchors = page.find_all('a', class_='jobtitle')
    for a in anchors:
        job_links.append('https://www.indeed.com' + a.get('href'))

# %% [markdown]
# # Get list of job description

# %%
job_description = []
bad_attemps = []
for link in job_links:
    r = requests.get(link)
    page = BeautifulSoup(r.content, 'html.parser')
    try:
        description = page.find('div', class_='jobsearch-jobDescriptionText').text.replace('\n', ' ')
    except:
        bad_attemps.append(link)
        continue
    job_description.append(description)
        
for link in bad_attemps:
    job_links.remove(link)

# %%
print(len(job_links))
print(len(job_description))
# Out:
# 372
# 372

# %%
jobs = pd.DataFrame({'URL': job_links, 'description': job_description})

# %%
symbols = "!\"#$%&()*+-./:;<=>?@[\]^_`{|}~\n"

def remove_symbols(description):
    for i in symbols:
        description = description.replace(i, ' ')
    return description

# transform to lowercase
jobs['description'] = jobs['description'].apply(lambda x: x.lower())
# removing the symbols
jobs['description'] = jobs['description'].apply(lambda x: remove_symbols(x))
jobs
# Out:
#                                                    URL  \
# 0    https://www.indeed.com/rc/clk?jk=6da90d3e35dc3...
# 1    https://www.indeed.com/rc/clk?jk=1ef88d6418dca...
# 2    https://www.indeed.com/rc/clk?jk=bb7e03808b04c...
# 3    https://www.indeed.com/rc/clk?jk=7689940b1824c...
# 4    https://www.indeed.com/rc/clk?jk=781d6e38e647e...
# ..                                                 ...
# 367  https://www.indeed.com/rc/clk?jk=cc0f3f8cafc80...
# 368  https://www.indeed.com/rc/clk?jk=e65cb176dca08...
# 369  https://www.indeed.com/rc/clk?jk=3a815ac96c8ac...
# 370  https://www.indeed.com/rc/clk?jk=061a8dd5c5308...
# 371  https://www.indeed.com/rc/clk?jk=f94e4bea2baef...
#
#                                            description
# 0    nossa gente aqui na cervejaria ambev sonha gra...
# 1    conheça a nossa banda  inovadora  diferente  d...
# 2    ajudamos empresas  nacionais e internacionais ...
# 3        vaga de um cliente da talentbrand     desc...
# 4    atribuições  projetar soluções para armazenar ...
# ..                                                 ...
# 367  a eleflow nasceu para tornar big data analytic...
# 368  como você pode transformar o brasil por meio d...
# 369  como desenvolvedor backend ou fullstack o prof...
# 370  o descomplica é uma plataforma de educação dig...
# 371  atividades o que você irá fazer   produzir sol...
#
# [372 rows x 2 columns]

# %% [markdown]
# # Tf_idf calc

# %% [markdown]
# ### Set of words in corpus

# %%
words = []
for tf in jobs['description']:
    words.extend(tf.split(' '))
word_set = set(words)
word_set.remove('')

# %% [markdown]
# ### word counting

# %%
def word_count(description):
    word_dict = {}
    for i in word_set:
        word_dict[i] = description.count(i)
    return word_dict

# %%
jobs['word_count'] = jobs['description'].apply(word_count)
jobs
# Out:
#                                                    URL  \
# 0    https://www.indeed.com/rc/clk?jk=6da90d3e35dc3...
# 1    https://www.indeed.com/rc/clk?jk=1ef88d6418dca...
# 2    https://www.indeed.com/rc/clk?jk=bb7e03808b04c...
# 3    https://www.indeed.com/rc/clk?jk=7689940b1824c...
# 4    https://www.indeed.com/rc/clk?jk=781d6e38e647e...
# ..                                                 ...
# 367  https://www.indeed.com/rc/clk?jk=cc0f3f8cafc80...
# 368  https://www.indeed.com/rc/clk?jk=e65cb176dca08...
# 369  https://www.indeed.com/rc/clk?jk=3a815ac96c8ac...
# 370  https://www.indeed.com/rc/clk?jk=061a8dd5c5308...
# 371  https://www.indeed.com/rc/clk?jk=f94e4bea2baef...
#
#                                            description  \
# 0    nossa gente aqui na cervejaria ambev sonha gra...
# 1    conheça a nossa banda  inovadora  diferente  d...
# 2    ajudamos empresas  nacionais e internacionais ...
# 3        vaga de um cliente da talentbrand     desc...
# 4    atribuições  projetar soluções para armazenar ...
# ..                                                 ...
# 367  a eleflow nasceu para tornar big data analytic...
# 368  como você pode transformar o brasil por meio d...
# 369  como desenvolvedor backend ou fullstack o prof...
# 370  o descomplica é uma plataforma de educação dig...
# 371  atividades o que você irá fazer   produzir sol...
#
#                                             word_count  \
# 0    {'cadastre': 0, 'comitê': 0, 'who': 0, 'cumpri...
# 1    {'cadastre': 0, 'comitê': 0, 'who': 0, 'cumpri...
# 2    {'cadastre': 0, 'comitê': 0, 'who': 0, 'cumpri...
# 3    {'cadastre': 0, 'comitê': 0, 'who': 0, 'cumpri...
# 4    {'cadastre': 0, 'comitê': 0, 'who': 0, 'cumpri...
# ..                                                 ...
# 367  {'cadastre': 0, 'comitê': 0, 'who': 0, 'cumpri...
# 368  {'cadastre': 0, 'comitê': 0, 'who': 0, 'cumpri...
# 369  {'cadastre': 0, 'comitê': 0, 'who': 0, 'cumpri...
# 370  {'cadastre': 0, 'comitê': 0, 'who': 0, 'cumpri...
# 371  {'cadastre': 0, 'comitê': 0, 'who': 0, 'cumpri...
#
#                                                     tf  \
# 0    {'nossa': 0.0057306590257879654, 'gente': 0.01...
# 1    {'conheça': 0.002570694087403599, 'a': 0.02056...
# 2    {'ajudamos': 0.0027247956403269754, 'empresas'...
# 3    {'': 0.14930555555555555, 'vaga': 0.0138888888...
# 4    {'atribuições': 0.00510204081632653, '': 0.168...
# ..                                                 ...
# 367  {'a': 0.01098901098901099, 'eleflow': 0.010989...
# 368  {'como': 0.002840909090909091, 'você': 0.00994...
# 369  {'como': 0.008130081300813009, 'desenvolvedor'...
# 370  {'o': 0.006119951040391677, 'descomplica': 0.0...
# 371  {'atividades': 0.002890173410404624, 'o': 0.00...
#
#                                                  tfidf
# 0      (0, 6059)\t0.08226105041815429\n  (0, 1953)\...
# 1      (0, 6059)\t0.08226105041815429\n  (0, 1953)\...
# 2      (0, 6059)\t0.08226105041815429\n  (0, 1953)\...
# 3      (0, 6059)\t0.08226105041815429\n  (0, 1953)\...
# 4      (0, 6059)\t0.08226105041815429\n  (0, 1953)\...
# ..                                                 ...
# 367    (0, 6059)\t0.08226105041815429\n  (0, 1953)\...
# 368    (0, 6059)\t0.08226105041815429\n  (0, 1953)\...
# 369    (0, 6059)\t0.08226105041815429\n  (0, 1953)\...
# 370    (0, 6059)\t0.08226105041815429\n  (0, 1953)\...
# 371    (0, 6059)\t0.08226105041815429\n  (0, 1953)\...
#
# [372 rows x 5 columns]

# %% [markdown]
# ### Term frequencies in job description

# %%
def tf(counter):
    tf_dict = {}
    counter_len = sum(counter.values())
    for key, value in counter.items():
        tf_dict[key] = value / counter_len
    return tf_dict

# %%
jobs['tf'] = jobs['word_count'].apply(tf)
jobs
# Out:
#                                                    URL  \
# 0    https://www.indeed.com/rc/clk?jk=6da90d3e35dc3...
# 1    https://www.indeed.com/rc/clk?jk=1ef88d6418dca...
# 2    https://www.indeed.com/rc/clk?jk=bb7e03808b04c...
# 3    https://www.indeed.com/rc/clk?jk=7689940b1824c...
# 4    https://www.indeed.com/rc/clk?jk=781d6e38e647e...
# ..                                                 ...
# 367  https://www.indeed.com/rc/clk?jk=cc0f3f8cafc80...
# 368  https://www.indeed.com/rc/clk?jk=e65cb176dca08...
# 369  https://www.indeed.com/rc/clk?jk=3a815ac96c8ac...
# 370  https://www.indeed.com/rc/clk?jk=061a8dd5c5308...
# 371  https://www.indeed.com/rc/clk?jk=f94e4bea2baef...
#
#                                            description  \
# 0    nossa gente aqui na cervejaria ambev sonha gra...
# 1    conheça a nossa banda  inovadora  diferente  d...
# 2    ajudamos empresas  nacionais e internacionais ...
# 3        vaga de um cliente da talentbrand     desc...
# 4    atribuições  projetar soluções para armazenar ...
# ..                                                 ...
# 367  a eleflow nasceu para tornar big data analytic...
# 368  como você pode transformar o brasil por meio d...
# 369  como desenvolvedor backend ou fullstack o prof...
# 370  o descomplica é uma plataforma de educação dig...
# 371  atividades o que você irá fazer   produzir sol...
#
#                                             word_count  \
# 0    {'cadastre': 0, 'comitê': 0, 'who': 0, 'cumpri...
# 1    {'cadastre': 0, 'comitê': 0, 'who': 0, 'cumpri...
# 2    {'cadastre': 0, 'comitê': 0, 'who': 0, 'cumpri...
# 3    {'cadastre': 0, 'comitê': 0, 'who': 0, 'cumpri...
# 4    {'cadastre': 0, 'comitê': 0, 'who': 0, 'cumpri...
# ..                                                 ...
# 367  {'cadastre': 0, 'comitê': 0, 'who': 0, 'cumpri...
# 368  {'cadastre': 0, 'comitê': 0, 'who': 0, 'cumpri...
# 369  {'cadastre': 0, 'comitê': 0, 'who': 0, 'cumpri...
# 370  {'cadastre': 0, 'comitê': 0, 'who': 0, 'cumpri...
# 371  {'cadastre': 0, 'comitê': 0, 'who': 0, 'cumpri...
#
#                                                     tf
# 0    {'cadastre': 0.0, 'comitê': 0.0, 'who': 0.0, '...
# 1    {'cadastre': 0.0, 'comitê': 0.0, 'who': 0.0, '...
# 2    {'cadastre': 0.0, 'comitê': 0.0, 'who': 0.0, '...
# 3    {'cadastre': 0.0, 'comitê': 0.0, 'who': 0.0, '...
# 4    {'cadastre': 0.0, 'comitê': 0.0, 'who': 0.0, '...
# ..                                                 ...
# 367  {'cadastre': 0.0, 'comitê': 0.0, 'who': 0.0, '...
# 368  {'cadastre': 0.0, 'comitê': 0.0, 'who': 0.0, '...
# 369  {'cadastre': 0.0, 'comitê': 0.0, 'who': 0.0, '...
# 370  {'cadastre': 0.0, 'comitê': 0.0, 'who': 0.0, '...
# 371  {'cadastre': 0.0, 'comitê': 0.0, 'who': 0.0, '...
#
# [372 rows x 4 columns]

# %% [markdown]
# ### Inverse Document Frequencies

# %%
doc_freq = {}
for word in word_set:
    doc_freq[word] = 0

for word in word_set:
    for word_count in jobs['word_count']:
        if word_count[word] != 0:
            doc_freq[word] += 1

# %%
idf = {}
for word, freq in doc_freq.items():
    idf[word] = math.log(len(jobs)/(1 + freq))

# %% [markdown]
# ### TF-IDF calc

# %%
def tfidf_calc(tf):
    tfidf = {}
    for word in tf.keys():
        tfidf[word] = tf[word] * idf[word]
    return tfidf

# %%
jobs['tfidf'] = jobs['tf'].apply(tfidf_calc)
jobs
# Out:
#                                                    URL  \
# 0    https://www.indeed.com/rc/clk?jk=6da90d3e35dc3...
# 1    https://www.indeed.com/rc/clk?jk=1ef88d6418dca...
# 2    https://www.indeed.com/rc/clk?jk=bb7e03808b04c...
# 3    https://www.indeed.com/rc/clk?jk=7689940b1824c...
# 4    https://www.indeed.com/rc/clk?jk=781d6e38e647e...
# ..                                                 ...
# 367  https://www.indeed.com/rc/clk?jk=cc0f3f8cafc80...
# 368  https://www.indeed.com/rc/clk?jk=e65cb176dca08...
# 369  https://www.indeed.com/rc/clk?jk=3a815ac96c8ac...
# 370  https://www.indeed.com/rc/clk?jk=061a8dd5c5308...
# 371  https://www.indeed.com/rc/clk?jk=f94e4bea2baef...
#
#                                            description  \
# 0    nossa gente aqui na cervejaria ambev sonha gra...
# 1    conheça a nossa banda  inovadora  diferente  d...
# 2    ajudamos empresas  nacionais e internacionais ...
# 3        vaga de um cliente da talentbrand     desc...
# 4    atribuições  projetar soluções para armazenar ...
# ..                                                 ...
# 367  a eleflow nasceu para tornar big data analytic...
# 368  como você pode transformar o brasil por meio d...
# 369  como desenvolvedor backend ou fullstack o prof...
# 370  o descomplica é uma plataforma de educação dig...
# 371  atividades o que você irá fazer   produzir sol...
#
#                                             word_count  \
# 0    {'cadastre': 0, 'comitê': 0, 'who': 0, 'cumpri...
# 1    {'cadastre': 0, 'comitê': 0, 'who': 0, 'cumpri...
# 2    {'cadastre': 0, 'comitê': 0, 'who': 0, 'cumpri...
# 3    {'cadastre': 0, 'comitê': 0, 'who': 0, 'cumpri...
# 4    {'cadastre': 0, 'comitê': 0, 'who': 0, 'cumpri...
# ..                                                 ...
# 367  {'cadastre': 0, 'comitê': 0, 'who': 0, 'cumpri...
# 368  {'cadastre': 0, 'comitê': 0, 'who': 0, 'cumpri...
# 369  {'cadastre': 0, 'comitê': 0, 'who': 0, 'cumpri...
# 370  {'cadastre': 0, 'comitê': 0, 'who': 0, 'cumpri...
# 371  {'cadastre': 0, 'comitê': 0, 'who': 0, 'cumpri...
#
#                                                     tf  \
# 0    {'cadastre': 0.0, 'comitê': 0.0, 'who': 0.0, '...
# 1    {'cadastre': 0.0, 'comitê': 0.0, 'who': 0.0, '...
# 2    {'cadastre': 0.0, 'comitê': 0.0, 'who': 0.0, '...
# 3    {'cadastre': 0.0, 'comitê': 0.0, 'who': 0.0, '...
# 4    {'cadastre': 0.0, 'comitê': 0.0, 'who': 0.0, '...
# ..                                                 ...
# 367  {'cadastre': 0.0, 'comitê': 0.0, 'who': 0.0, '...
# 368  {'cadastre': 0.0, 'comitê': 0.0, 'who': 0.0, '...
# 369  {'cadastre': 0.0, 'comitê': 0.0, 'who': 0.0, '...
# 370  {'cadastre': 0.0, 'comitê': 0.0, 'who': 0.0, '...
# 371  {'cadastre': 0.0, 'comitê': 0.0, 'who': 0.0, '...
#
#                                                  tfidf
# 0    {'cadastre': 0.0, 'comitê': 0.0, 'who': 0.0, '...
# 1    {'cadastre': 0.0, 'comitê': 0.0, 'who': 0.0, '...
# 2    {'cadastre': 0.0, 'comitê': 0.0, 'who': 0.0, '...
# 3    {'cadastre': 0.0, 'comitê': 0.0, 'who': 0.0, '...
# 4    {'cadastre': 0.0, 'comitê': 0.0, 'who': 0.0, '...
# ..                                                 ...
# 367  {'cadastre': 0.0, 'comitê': 0.0, 'who': 0.0, '...
# 368  {'cadastre': 0.0, 'comitê': 0.0, 'who': 0.0, '...
# 369  {'cadastre': 0.0, 'comitê': 0.0, 'who': 0.0, '...
# 370  {'cadastre': 0.0, 'comitê': 0.0, 'who': 0.0, '...
# 371  {'cadastre': 0.0, 'comitê': 0.0, 'who': 0.0, '...
#
# [372 rows x 5 columns]

# %% [markdown]
# # Most important words of all jobs

# %%
word_importance = {}

# %%
for word in word_set:
    word_importance[word] = 0

# %%
for tfidf in jobs['tfidf']:
    for word, importance in word_importance.items():
        word_importance[word] += tfidf[word]

# %%
df_importance = pd.DataFrame({'word': word_importance.keys(), 'importance': word_importance.values()})
df_importance.sort_values(['importance'], ascending=False).head(20)
# Out:
#            word  importance
# 914           0    0.330835
# 4994   learning    0.315335
# 3086      learn    0.295363
# 1204    machine    0.281992
# 1299          k    0.266015
# 4063       vale    0.259421
# 4701         cs    0.256270
# 4470          2    0.254061
# 1026        you    0.250995
# 380      modelo    0.250935
# 4594          •    0.235393
# 6673   analytic    0.235114
# 3089  analytics    0.233210
# 7095  modelagem    0.230947
# 5208    modelos    0.225643
# 2529       mode    0.225306
# 2682       data    0.219890
# 2155    análise    0.219100
# 3398       soft    0.216860
# 5976        ano    0.212627
